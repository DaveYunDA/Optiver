# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

data = pd.read_csv('stock_1.csv')

# %% [markdown]
# ##EDA
#
# Lookin into the data bro

# %%
data.head()
# Out:
#    time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  ask_price2  \
# 0        5                  0    1.000754    1.001542    1.000689    1.001607
# 1        5                  1    1.000754    1.001673    1.000689    1.001739
# 2        5                  2    1.000754    1.001411    1.000623    1.001476
# 3        5                  3    1.000754    1.001542    1.000689    1.001607
# 4        5                  4    1.000754    1.001476    1.000623    1.001542
#
#    bid_size1  ask_size1  bid_size2  ask_size2  stock_id
# 0          1         25         25        100         1
# 1         26         60         25        100         1
# 2          1         25         25        125         1
# 3        125         25        126         36         1
# 4        100        100         25         25         1

# %%
data['timestamp'] = pd.to_datetime(data['time_id'] * 1000 + data['seconds_in_bucket'], unit='ms')
data.set_index('timestamp', inplace=True)

data['bid_price1'].plot()
plt.xlabel('Timestamp')
plt.ylabel('Bid Price 1')
plt.show()
